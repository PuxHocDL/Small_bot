# %%
from config import get_config
cfg = get_config()
cfg['batch_size'] = 6
cfg['preload'] = None
cfg['num_epochs'] = 30

from train import train_model

train_model(cfg)
# Out:
# Thiết bị đang sử dụng: cpu
# Lưu ý: Nếu bạn có GPU, hãy cân nhắc sử dụng nó để huấn luyện.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 9
#       5 cfg['num_epochs'] = 30
#       7 from train import train_model
# ----> 9 train_model(cfg)
#
# File c:\Users\ASUS ExpertBook\Desktop\Buoi6\train.py:194, in train_model(config)
#     191 Path(f"{config['datasource']}_{config['model_folder']}").mkdir(parents=True, exist_ok=True)
#     193 # Nạp dữ liệu huấn luyện và kiểm tra
# --> 194 train_dataloader, val_dataloader, tokenizer_src, tokenizer_tgt = get_ds(config)
#     195 # Khởi tạo mô hình Transformer
#     196 model = get_model(config, tokenizer_src.get_vocab_size(), tokenizer_tgt.get_vocab_size()).to(device)
#
# File c:\Users\ASUS ExpertBook\Desktop\Buoi6\train.py:152, in get_ds(config)
#     150 def get_ds(config):
#     151     # Tải dataset từ Hugging Face
# ...
